# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras import Model, Sequential
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import LSTM, Dense, RepeatVector, Dropout, TimeDistributed

import warnings

# %%
plt.rcParams['figure.figsize'] = (10,4)
sns.set()
warnings.filterwarnings('ignore')

# %%
path = '/content/drive/MyDrive/nyc_taxi.csv'
data = pd.read_csv(path, parse_dates=['timestamp'], index_col='timestamp')
data.head()
# Out:
#                      value
# timestamp
# 2014-07-01 00:00:00  10844
# 2014-07-01 00:30:00   8127
# 2014-07-01 01:00:00   6210
# 2014-07-01 01:30:00   4656
# 2014-07-01 02:00:00   3820

# %%
period = 48
print(data.index[:period])
# Out:
# DatetimeIndex(['2014-07-01 00:00:00', '2014-07-01 00:30:00',
#                '2014-07-01 01:00:00', '2014-07-01 01:30:00',
#                '2014-07-01 02:00:00', '2014-07-01 02:30:00',
#                '2014-07-01 03:00:00', '2014-07-01 03:30:00',
#                '2014-07-01 04:00:00', '2014-07-01 04:30:00',
#                '2014-07-01 05:00:00', '2014-07-01 05:30:00',
#                '2014-07-01 06:00:00', '2014-07-01 06:30:00',
#                '2014-07-01 07:00:00', '2014-07-01 07:30:00',
#                '2014-07-01 08:00:00', '2014-07-01 08:30:00',
#                '2014-07-01 09:00:00', '2014-07-01 09:30:00',
#                '2014-07-01 10:00:00', '2014-07-01 10:30:00',
#                '2014-07-01 11:00:00', '2014-07-01 11:30:00',
#                '2014-07-01 12:00:00', '2014-07-01 12:30:00',
#                '2014-07-01 13:00:00', '2014-07-01 13:30:00',
#                '2014-07-01 14:00:00', '2014-07-01 14:30:00',
#                '2014-07-01 15:00:00', '2014-07-01 15:30:00',
#                '2014-07-01 16:00:00', '2014-07-01 16:30:00',
#                '2014-07-01 17:00:00', '2014-07-01 17:30:00',
#                '2014-07-01 18:00:00', '2014-07-01 18:30:00',
#                '2014-07-01 19:00:00', '2014-07-01 19:30:00',
#                '2014-07-01 20:00:00', '2014-07-01 20:30:00',
#                '2014-07-01 21:00:00', '2014-07-01 21:30:00',
#                '2014-07-01 22:00:00', '2014-07-01 22:30:00',
#                '2014-07-01 23:00:00', '2014-07-01 23:30:00'],
#               dtype='datetime64[ns]', name='timestamp', freq=None)

# %%
print('From  ' + str(np.min(data.index)) + '  to  ' +str(np.max(data.index)))
# Out:
# From  2014-07-01 00:00:00  to  2015-01-31 23:30:00

# %%
print('Data size: %d \nNumber of data per day: %d \nNumber of days: %d' %(data.shape[0], period, data.shape[0] / period))
# Out:
# Data size: 10320
# Number of data per day: 48
# Number of days: 215

# %%
print('Missing value: ', data.isnull().to_numpy().sum())
# Out:
# Missing value:  0

# %%
data.plot(title='Data points', figsize=(30,4))
plt.show()

# %%
for i in range(5):
    data[period*i:period*(i + 1)].plot(figsize=(5, 2), title=str(data.index[period * i])[:10])
    plt.xlabel(None)
    plt.show()

# %%
from sklearn.model_selection import TimeSeriesSplit

# Shuffle the data
data_shuffled = data.sample(frac=1, random_state=42)  # Shuffle the data using a fixed random state

# Define the ratio for training data
ratio = 0.7  # 70% of the data for training

# Split the shuffled data into training and test sets
train_size = int(data_shuffled.shape[0] * ratio)
train = data_shuffled[:train_size]
test = data_shuffled[train_size:]

# Extract dates for train and test sets
dates_train = train.index
dates_test = test.index

# Print information about train and test sets
print('Train size: ', ratio)
print('\n TRAIN SET')
print('Data size: ', train.shape[0])
print('Number of days: ', int(train.shape[0] / period))

print('\n TEST SET')
print('Data size: ', test.shape[0])
print('Number of days: ', int(test.shape[0] / period))
# Out:
# Train size:  0.7
#
#  TRAIN SET
# Data size:  7223
# Number of days:  150
#
#  TEST SET
# Data size:  3097
# Number of days:  64

# %%
#plots
plt.figure(figsize=(30,4))
plt.title('Train set')
plt.plot(train.to_numpy().flatten())
plt.show()

plt.figure(figsize=(30,4))
plt.title('Test set')
plt.plot(test.to_numpy().flatten())
plt.show()

# %%
scaler = StandardScaler()
scaler = scaler.fit(train.values.reshape(-1, 1))

train = scaler.transform(train.values.reshape(-1, 1))
test = scaler.transform(test.values.reshape(-1, 1))

# %%
def split_into_windows(X, length):
    windows = []
    num_windows = len(X) - length + 1
    for start in range(num_windows):
        window = X[start:start + length]
        windows.append(window)
    return np.array(windows)

window_length = 48
X_train = split_into_windows(train, window_length)
X_test = split_into_windows(test, window_length)

# %%
_, input_length, input_dim = X_train.shape
X_train.shape
# Out:
# (7176, 48, 1)

# %%
# params
dim_hidden1 = 24 # 1/2 the length of one window
dim_hidden2 = 12 # 1/4 the length of one window


# model
model = Sequential()
model.add(LSTM(units=dim_hidden1, activation='relu', input_shape=(input_length, input_dim), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=dim_hidden2, activation='relu', return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=dim_hidden2, activation='relu', return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=dim_hidden1, activation='relu', return_sequences=True))
model.add(Dropout(0.2))
model.add(Dense(1))

# summary
model.compile(loss='mse', optimizer='adam')
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 48, 24)            2496
#
#  dropout (Dropout)           (None, 48, 24)            0
#
#  lstm_1 (LSTM)               (None, 48, 12)            1776
#
#  dropout_1 (Dropout)         (None, 48, 12)            0
#
#  lstm_2 (LSTM)               (None, 48, 12)            1200
#
#  dropout_2 (Dropout)         (None, 48, 12)            0
#
#  lstm_3 (LSTM)               (None, 48, 24)            3552
#
#  dropout_3 (Dropout)         (None, 48, 24)            0
#
#  dense (Dense)               (None, 48, 1)             25
#
# =================================================================
# Total params: 9049 (35.35 KB)
# Trainable params: 9049 (35.35 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# params
batch_size = 48 # 24 hours == length of the window
epochs = 50
validation_split = 0.1
es = EarlyStopping(monitor='val_loss', patience=5)


# fitting
history = model.fit(X_train, X_train,
                batch_size = batch_size,
                epochs = epochs,
                validation_split = validation_split,
                callbacks = [es])
# Out:
# Epoch 1/50
# 135/135 [==============================] - 16s 83ms/step - loss: 0.9815 - val_loss: 0.5818
# Epoch 2/50
# 135/135 [==============================] - 9s 64ms/step - loss: 0.4238 - val_loss: 0.1198
# Epoch 3/50
# 135/135 [==============================] - 9s 66ms/step - loss: 0.1829 - val_loss: 0.0708
# Epoch 4/50
# 135/135 [==============================] - 9s 70ms/step - loss: 0.1279 - val_loss: 0.0436
# Epoch 5/50
# 135/135 [==============================] - 8s 62ms/step - loss: 0.1036 - val_loss: 0.0403
# Epoch 6/50
# 135/135 [==============================] - 9s 67ms/step - loss: 0.0894 - val_loss: 0.0271
# Epoch 7/50
# 135/135 [==============================] - 9s 70ms/step - loss: 0.0807 - val_loss: 0.0259
# Epoch 8/50
# 135/135 [==============================] - 8s 61ms/step - loss: 0.0747 - val_loss: 0.0240
# Epoch 9/50
# 135/135 [==============================] - 9s 68ms/step - loss: 0.0701 - val_loss: 0.0225
# Epoch 10/50
# 135/135 [==============================] - 9s 70ms/step - loss: 0.0662 - val_loss: 0.0218
# Epoch 11/50
# 135/135 [==============================] - 8s 60ms/step - loss: 0.0639 - val_loss: 0.0204
# Epoch 12/50
# 135/135 [==============================] - 9s 70ms/step - loss: 0.0611 - val_loss: 0.0174
# Epoch 13/50
# 135/135 [==============================] - 9s 70ms/step - loss: 0.0591 - val_loss: 0.0195
# Epoch 14/50
# 135/135 [==============================] - 8s 60ms/step - loss: 0.0574 - val_loss: 0.0209
# Epoch 15/50
# 135/135 [==============================] - 9s 69ms/step - loss: 0.0556 - val_loss: 0.0184
# Epoch 16/50
# 135/135 [==============================] - 9s 69ms/step - loss: 0.0542 - val_loss: 0.0150
# Epoch 17/50
# 135/135 [==============================] - 8s 60ms/step - loss: 0.0529 - val_loss: 0.0138
# Epoch 18/50
# 135/135 [==============================] - 15s 108ms/step - loss: 0.0519 - val_loss: 0.0144
# Epoch 19/50
# 135/135 [==============================] - 9s 70ms/step - loss: 0.0507 - val_loss: 0.0150
# Epoch 20/50
# 135/135 [==============================] - 9s 70ms/step - loss: 0.0497 - val_loss: 0.0140
# Epoch 21/50
# 135/135 [==============================] - 8s 60ms/step - loss: 0.0486 - val_loss: 0.0165
# Epoch 22/50
# 135/135 [==============================] - 9s 69ms/step - loss: 0.0476 - val_loss: 0.0134
# Epoch 23/50
# 135/135 [==============================] - 9s 70ms/step - loss: 0.0470 - val_loss: 0.0135
# Epoch 24/50
# 135/135 [==============================] - 8s 60ms/step - loss: 0.0461 - val_loss: 0.0163
# Epoch 25/50
# 135/135 [==============================] - 9s 70ms/step - loss: 0.0455 - val_loss: 0.0138
# Epoch 26/50
# 135/135 [==============================] - 9s 70ms/step - loss: 0.0446 - val_loss: 0.0161
# Epoch 27/50
# 135/135 [==============================] - 8s 60ms/step - loss: 0.0442 - val_loss: 0.0175

# %%
plt.title('Loss')
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()
plt.show()

# %%
pred_x_test = model.predict(X_test)
pred_x_train = model.predict(X_train)
# Out:
# 96/96 [==============================] - 2s 14ms/step
# 225/225 [==============================] - 3s 14ms/step

# %%
for i in range(int(period / window_length)):
    x = X_test[i * window_length].flatten()
    x_pred = pred_x_test[i * window_length].flatten()

    plt.plot(x, label='x')
    plt.plot(x_pred, label='reconstruction')
    plt.fill_between(np.arange(window_length), x, x_pred, alpha=0.2, label='error')
    plt.legend()
    plt.show()

# %%
mse = lambda x, x_pred: np.mean(np.abs(x - x_pred)**2, axis=1)

train_mae_loss = pd.DataFrame(mse(X_train, pred_x_train), columns=['Error'])
test_mae_loss = pd.DataFrame(mse(X_test, pred_x_test), columns=['Error'])

# %%
plt.title('Loss distribution - train set')
sns.distplot(train_mae_loss, bins=100, kde=True)
plt.show()

plt.title('Loss distribution - test set')
sns.distplot(test_mae_loss, bins=100, kde=True)
plt.show()

# %%
test_mae_loss_array = test_mae_loss.to_numpy().flatten()

plt.figure(figsize=(20,4))
plt.plot(test_mae_loss_array, label='loss')
plt.legend()
plt.show()

# %%
print(np.mean(test_mae_loss)[0] + 2 * np.std(test_mae_loss)[0])
# Out:
# 0.03236741379905325

# %%
threshold = 0.025

# %%
test_mae_loss_array = test_mae_loss.to_numpy().flatten()


plt.figure(figsize=(20,4))
plt.plot(test_mae_loss_array, label='loss')
plt.axhline(threshold, color='red', label='threshold')
plt.legend()
plt.show()

# %%
y_pred = test_mae_loss_array >= threshold
y_pred.shape
# Out:
# (3050,)

# %%
dates_test[:-(window_length-1)].shape
# Out:
# (3050,)

# %%
dates_with_hours_anomalies = dates_test[:-(window_length-1)][y_pred]

print('Dates where anomalies have been detected:')
for d in dates_with_hours_anomalies:
    print(d)
# Out:
# Dates where anomalies have been detected:
# 2014-08-19 21:30:00
# 2014-07-31 19:00:00
# 2014-12-21 06:30:00
# 2014-08-17 06:30:00
# 2015-01-07 00:00:00
# 2014-10-11 10:00:00
# 2014-10-19 21:00:00
# 2014-10-29 06:30:00
# 2014-11-07 20:00:00
# 2014-09-21 11:00:00
# 2014-10-12 17:30:00
# 2014-12-17 03:00:00
# 2014-11-13 23:00:00
# 2015-01-30 05:00:00
# 2014-07-19 05:00:00
# 2014-08-17 20:30:00
# 2014-08-25 01:30:00
# 2014-10-11 22:00:00
# 2014-11-03 18:00:00
# 2014-10-08 23:00:00
# 2015-01-02 20:30:00
# 2014-10-04 16:00:00
# 2014-07-04 09:30:00
# 2015-01-28 19:30:00
# 2015-01-19 19:00:00
# 2015-01-27 04:30:00
# 2014-11-05 22:00:00
# 2014-12-11 16:30:00
# 2014-09-07 19:00:00
# 2014-10-03 02:30:00
# 2015-01-12 03:30:00
# 2014-07-30 05:30:00
# 2014-07-29 19:00:00
# 2014-11-22 08:00:00
# 2014-10-27 03:30:00
# 2014-10-22 05:30:00
# 2014-07-31 01:00:00
# 2014-09-30 19:00:00
# 2015-01-21 22:00:00
# 2014-08-05 04:30:00
# 2015-01-29 02:30:00
# 2014-11-02 05:00:00
# 2014-08-22 00:00:00
# 2014-12-24 07:00:00
# 2014-07-08 02:00:00
# 2014-08-20 04:00:00
# 2014-07-22 02:00:00
# 2014-10-19 00:00:00
# 2014-08-06 07:00:00
# 2014-08-15 21:30:00
# 2014-09-13 08:00:00
# 2014-11-05 10:00:00
# 2015-01-31 08:30:00
# 2014-11-04 02:00:00
# 2014-09-05 05:00:00
# 2014-07-05 10:30:00
# 2014-07-17 05:00:00
# 2014-09-11 20:00:00
# 2015-01-06 13:30:00
# 2014-08-12 13:30:00
# 2014-10-21 22:00:00
# 2014-11-06 05:00:00
# 2014-12-22 02:30:00
# 2015-01-04 03:30:00
# 2014-12-24 08:30:00
# 2014-09-25 19:30:00
# 2014-09-17 22:00:00
# 2014-07-13 03:30:00
# 2015-01-30 01:00:00
# 2015-01-31 17:00:00
# 2014-07-03 10:00:00
# 2014-11-16 10:00:00
# 2015-01-11 05:00:00
# 2015-01-30 22:00:00
# 2015-01-09 15:00:00
# 2014-12-29 12:00:00
# 2014-08-06 17:30:00
# 2014-08-09 01:30:00
# 2014-09-06 04:00:00
# 2014-07-11 23:00:00
# 2014-12-08 22:30:00
# 2014-08-31 09:00:00
# 2014-10-02 04:30:00
# 2014-10-26 19:30:00
# 2014-11-04 05:30:00
# 2014-07-20 23:30:00
# 2014-11-10 03:00:00
# 2014-09-14 16:30:00
# 2014-07-22 21:00:00
# 2014-12-29 11:30:00
# 2014-09-09 10:00:00
# 2014-09-15 14:00:00
# 2014-10-29 08:00:00
# 2015-01-11 11:00:00
# 2014-11-14 22:30:00
# 2014-10-14 22:30:00
# 2014-09-07 15:00:00
# 2014-11-18 08:30:00
# 2014-08-01 06:00:00
# 2015-01-04 21:00:00
# 2014-08-01 16:30:00
# 2015-01-12 23:30:00
# 2014-09-27 04:00:00
# 2014-12-08 03:00:00
# 2014-12-31 18:00:00
# 2014-10-01 07:00:00
# 2014-07-09 03:00:00
# 2015-01-28 22:00:00
# 2014-11-26 10:00:00
# 2014-11-01 04:30:00
# 2014-12-27 00:00:00
# 2014-10-09 03:00:00
# 2015-01-09 12:00:00
# 2014-12-19 15:00:00
# 2014-12-15 14:00:00
# 2015-01-27 07:00:00
# 2014-08-13 21:00:00
# 2014-08-25 19:30:00
# 2014-07-29 21:30:00
# 2015-01-09 00:30:00
# 2015-01-24 16:30:00
# 2014-11-25 13:30:00
# 2014-07-27 15:30:00
# 2014-07-17 18:00:00
# 2014-08-02 09:30:00
# 2015-01-20 22:00:00
# 2014-10-04 03:00:00
# 2015-01-24 21:30:00
# 2014-10-09 20:30:00
# 2014-09-13 21:00:00
# 2014-11-03 17:30:00
# 2014-11-20 18:00:00
# 2014-12-29 08:30:00
# 2014-09-26 00:30:00
# 2014-07-28 06:00:00
# 2015-01-06 17:00:00
# 2014-09-10 22:00:00
# 2014-09-15 23:30:00
# 2014-09-27 09:00:00
# 2014-08-15 19:00:00
# 2015-01-03 19:00:00
# 2014-10-01 04:30:00
# 2014-11-06 03:00:00
# 2014-07-20 15:30:00
# 2014-07-18 03:00:00
# 2014-10-13 06:30:00
# 2014-11-15 18:00:00
# 2014-12-22 02:00:00
# 2014-10-26 01:30:00
# 2014-10-03 17:30:00
# 2014-08-22 21:00:00
# 2014-10-17 11:30:00
# 2015-01-21 12:00:00
# 2015-01-10 17:00:00
# 2014-09-02 15:00:00
# 2014-09-15 13:30:00
# 2014-12-10 00:00:00
# 2014-11-28 09:00:00
# 2014-11-18 01:00:00
# 2014-09-07 18:00:00
# 2014-09-07 23:00:00
# 2014-11-28 10:30:00
# 2014-12-25 11:30:00
# 2014-11-02 01:00:00
# 2014-11-23 10:30:00
# 2014-11-17 02:30:00
# 2014-10-08 16:00:00
# 2015-01-20 07:00:00
# 2014-11-23 05:00:00
# 2014-09-20 18:30:00
# 2014-09-25 15:00:00
# 2014-12-03 04:30:00
# 2014-12-23 07:30:00
# 2014-08-15 16:30:00
# 2014-07-22 03:30:00
# 2014-08-04 23:00:00
# 2014-11-21 14:00:00
# 2014-11-10 19:00:00
# 2014-12-05 19:00:00
# 2014-08-28 03:00:00
# 2014-07-31 22:00:00
# 2014-10-15 23:00:00
# 2014-07-05 07:00:00
# 2014-10-02 12:00:00
# 2014-11-22 13:00:00
# 2015-01-05 19:00:00
# 2014-11-21 23:00:00
# 2014-12-01 20:30:00
# 2014-07-22 10:00:00
# 2014-09-19 00:00:00
# 2014-12-16 23:00:00
# 2014-10-14 08:00:00
# 2015-01-20 09:00:00
# 2014-12-17 21:00:00
# 2014-08-26 21:30:00
# 2015-01-04 10:00:00
# 2014-08-21 03:00:00
# 2014-11-28 07:30:00
# 2014-09-03 16:00:00
# 2014-12-22 20:00:00
# 2014-11-08 19:00:00

# %%
indexes = []
for d in dates_with_hours_anomalies:
    index_low = np.where(dates_test == d)
    d_temp = d  + np.timedelta64(int(window_length / 2), 'h')
    indexes.append(index_low[0][0])

# %%
plt.figure(figsize=(30,4))
for index in indexes:
    plt.axvspan(index, index, color='r', alpha=0.3)
plt.plot(scaler.inverse_transform(test).flatten())
plt.legend(['data', 'anomaly'])
plt.show()
